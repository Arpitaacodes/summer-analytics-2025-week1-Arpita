# %% [markdown]
# ![OIP (1).jpg](data:image/jpeg;base64,...)

# %% [markdown]
#  **Checkpoint!!
# Congratulations on making it this far. You are really keeping up in Data Grand Prix.
# Now starts the real race i.e. graded questions of the quiz.**

# %% [markdown]
# ## GRADED Questions (To be answered in the quiz)
# ### Try to retrieve some information from the data and answer the questions below . BEST OF LUCK !!

# %% [markdown]
# ### 1. What is name of car that has the highest horsepower?

# %%
#your code here

import pandas as pd

df = pd.read_csv("Cars.csv")


max_hp = df['horsepower'].max()


car_with_max_hp = df[df['horsepower'] == max_hp]


print(car_with_max_hp[['name', 'horsepower']])
# Out:
#                    name  horsepower
# 116  pontiac grand prix       230.0

# %% [markdown]
# ### 2. How many cars have mpg ≥ 35?

# %%
#your code here
df = pd.read_csv("Cars.csv")
cars_with_high_mpg = df[df['mpg'] >= 35]
num_cars_high_mpg = cars_with_high_mpg.shape[0]
print("2. Number of cars with mpg ≥ 35:", num_cars_high_mpg)
# Out:
# 2. Number of cars with mpg ≥ 35: 36

# %% [markdown]
# ### 3. What is the most common origin for cars with horsepower > 100 and weight < 3000?

# %%
#your code here
df = pd.read_csv("Cars.csv")
filtered_cars_q3 = df[(df['horsepower'] > 100) & (df['weight'] < 3000)]
most_common_origin_q3 = filtered_cars_q3['origin'].mode()[0]
print("3. Most common origin for cars with horsepower > 100 and weight < 3000:", most_common_origin_q3)
# Out:
# 3. Most common origin for cars with horsepower > 100 and weight < 3000: usa

# %% [markdown]
# ### 4. What is the mean acceleration of cars from Japan? (rounded to 2 decimals)

# %%
#your code here
df = pd.read_csv("Cars.csv")
mean_acc_japan = round(df[df['origin'] == 'japan']['acceleration'].mean(), 2)
print("4. Mean acceleration of cars from Japan:", mean_acc_japan)
# Out:
# 4. Mean acceleration of cars from Japan: 16.17

# %% [markdown]
# ### 5. Which year had the highest average mpg?

# %%
#your code here
df = pd.read_csv("Cars.csv")
year_with_highest_avg_mpg = df.groupby('model_year')['mpg'].mean().idxmax()
print("5. Year with the highest average mpg:", year_with_highest_avg_mpg)
# Out:
# 5. Year with the highest average mpg: 80

# %% [markdown]
# ## *Congratulations on coming this far! Since we were having so much fun playing with this dataset, let's move towards finish line by attempting some Ungraded questions!*
#
# ### **Note:** These questions are UNGRADED, and are given as an extra exercise.

# %% [markdown]
# ### Find the car (or cars) with the best ratio of horsepower to weight among all cars that also have above-median mpg.

# %%
#your code here
import pandas as pd

df = pd.read_csv("Cars.csv")

median_mpg = df['mpg'].median()
above_median_mpg = df[df['mpg'] > median_mpg].copy()

above_median_mpg['hp_to_weight'] = above_median_mpg['horsepower'] / above_median_mpg['weight']

max_ratio = above_median_mpg['hp_to_weight'].max()
best_ratio_cars = above_median_mpg[above_median_mpg['hp_to_weight'] == max_ratio]
print(best_ratio_cars[['name', 'hp_to_weight']])
# Out:
#         name  hp_to_weight
# 23  bmw 2002      0.050582

# %% [markdown]
# ### Design a multi-line plot using Matplotlib or Seaborn that shows the evolution of average mpg over the years, separately for each origin

# %%
#your code here

import matplotlib.pyplot as plt
import seaborn as sns
avg_mpg_by_year_origin = df.groupby(['model_year', 'origin'])['mpg'].mean().reset_index()
plt.figure(figsize=(10, 6))
sns.lineplot(data=avg_mpg_by_year_origin, x='model_year', y='mpg', hue='origin', marker='o')
plt.title('Evolution of Average MPG Over the Years by Origin')
plt.xlabel('Model Year')
plt.ylabel('Average MPG')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Create a Seaborn scatterplot (or PairGrid) where:
#
# X = horsepower
#
# Y = weight
#
# Color by: origin
#
# Size by: mpg
#
# Hue order = ['japan', 'europe', 'usa']
#
# Add meaningful plot titles and axis titles.

# %%
#your code here
plt.figure(figsize=(10, 6))
sns.scatterplot(
    data=df,
    x='horsepower',
    y='weight',
    hue='origin',
    size='mpg',
    hue_order=['japan', 'europe', 'usa'],
    sizes=(20, 200),
    alpha=0.7
)
plt.title('Horsepower vs Weight of Cars (Size by MPG, Color by Origin)')
plt.xlabel('Horsepower')
plt.ylabel('Weight')
plt.legend(title='Origin', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### We define a “consistent” car model as one that was produced over multiple years and had very low variation in mpg across those years (standard deviation < 1.0).
#
# Tasks:
#
# Identify car names that appear in more than one model_year.
#
# For each such name, compute the standard deviation of mpg across years.
#
# Return the car(s) with the lowest variation in mpg, among those with at least 2 appearances and std(mpg) < 1.0.
#
# Report the model name(s), number of appearances, and the average mpg.
#
# Bonus:
# Sort the result by number of appearances (descending), then mpg (descending).

# %%
#your code here
import pandas as pd

df = pd.read_csv("Cars.csv")

car_years = df.groupby('name')['model_year'].nunique()
multi_year_cars = car_years[car_years > 1].index
df_multi = df[df['name'].isin(multi_year_cars)]

stats = df_multi.groupby('name').agg(
    mpg_std=('mpg', 'std'),
    appearances=('mpg', 'count'),
    avg_mpg=('mpg', 'mean')
).reset_index()

consistent_cars = stats[stats['mpg_std'] < 1.0]
consistent_cars_sorted = consistent_cars.sort_values(by=['appearances', 'avg_mpg'], ascending=[False, False])

print(consistent_cars_sorted[['name', 'appearances', 'avg_mpg']])
# Out:
#                          name  appearances    avg_mpg
# 26           ford galaxie 500            3  14.333333
# 41          plymouth fury iii            3  14.333333
# 49        toyota corolla 1200            2  31.500000
# 35                  mazda 626            2  31.450000
# 53          volkswagen rabbit            2  29.250000
# 21               datsun pl510            2  27.000000
# 45                  saab 99le            2  24.500000
# 51             toyota mark ii            2  19.500000
# 22                dodge aspen            2  18.850000
# 10  chevrolet chevelle malibu            2  17.500000
# 4            amc matador (sw)            2  14.500000
# 28      ford gran torino (sw)            2  13.500000
# 29                   ford ltd            2  13.500000

# %% [markdown]
# ![OIP.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Congratulations on completing the race. Kudos to you. Looking forward to meet you in next week.**
